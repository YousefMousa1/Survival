# %% [markdown]
# # T-JEPA on Colab
#
# GPU: Runtime → Change runtime type → GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/YousefMousa1/Survival.git Survival-1
# %cd /content/Survival-1

# %%
# !python -m pip install -r requirements.txt
# !python -m pip install torch lifelines scikit-learn pandas numpy

# %% [markdown]
# Upload `brca_metabric/` into the repo folder, or place it on Drive and point `--data-dir` there.

# %%
# !python survival_pipeline.py \
  --data-dir brca_metabric \
  --expression-file data_mrna_illumina_microarray_zscores_ref_diploid_samples.txt \
  --duration-col OS_MONTHS \
  --event-col OS_STATUS \
  --top-genes 5000 \
  --chunk-size 2000 \
  --tjepa-config configs/tjepa_default.json \
  --tjepa-device cuda \
  --output-dir outputs_tjepa
